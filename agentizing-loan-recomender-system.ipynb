# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/m-pesa-data/transanction.csv

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(f"🔑 Error: {e}")
# Out:
# ✅ Gemini API key setup complete.

# %%
# ============================================================
# 0. CLEAN UP OLD DATABASE
# ============================================================

import os

if os.path.exists("my_agent_data.db"):
    os.remove("my_agent_data.db")
print("✅ Cleaned up old database files")

# ============================================================
# 1. IMPORTS & SETUP
# ============================================================

import pandas as pd
from google.adk.agents import Agent, SequentialAgent
from google.adk.tools import FunctionTool
from google.genai import types
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner

retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],
)

# ============================================================
# 2. DATA PROCESSING TOOLS
# ============================================================

def load_data(csv_path: str = "/kaggle/input/m-pesa-data/transanction.csv") -> pd.DataFrame:
    df = pd.read_csv(csv_path)
    numeric_cols = ["Paid In", "Withdrawn", "Balance"]
    df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
    df.dropna(subset=["Balance"], inplace=True)
    return df

def clean_and_prepare_data(df: pd.DataFrame) -> pd.DataFrame:
    df["Completion Time"] = pd.to_datetime(df['Completion Time'], errors='coerce')
    numeric_cols = ["Paid In", "Withdrawn", "Balance"]
    df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors="coerce")
    df.dropna(subset=["Balance"], inplace=True)
    return df

def sort_and_prepare_time_series(df: pd.DataFrame) -> pd.DataFrame:
    df = df.sort_values(by="Completion Time")
    return df.set_index("Completion Time")

def categorize_transaction(details: str) -> str:
    if not isinstance(details, str):
        return "Uncategorized"
    dl = details.lower()
    if "pay bill" in dl:
        return "Bills"
    elif "mpesa" in dl or "customer payment" in dl:
        return "Income"
    elif "withdraw" in dl or "purchase" in dl:
        return "Expenses"
    else:
        return "Other"

def analyze_mpesa_data() -> dict:
    df = load_data()
    df = clean_and_prepare_data(df)
    df = sort_and_prepare_time_series(df)
    df["Category"] = df["Details"].apply(categorize_transaction)

    balance_stats = {
        "start_balance": float(df["Balance"].iloc[0]),
        "end_balance": float(df["Balance"].iloc[-1]),
        "min_balance": float(df["Balance"].min()),
        "max_balance": float(df["Balance"].max()),
        "avg_balance": float(df["Balance"].mean()),
    }

    category_spending = (
        df[df["Withdrawn"] > 0]
        .groupby("Category")["Withdrawn"]
        .sum()
        .sort_values(ascending=False)
        .to_dict()
    )

    income_total = float(df["Paid In"].sum())
    withdrawal_total = float(df["Withdrawn"].sum())

    return {
        "balance_stats": balance_stats,
        "category_spending": category_spending,
        "income_total": income_total,
        "withdrawal_total": withdrawal_total,
    }

analyze_data_tool = FunctionTool(analyze_mpesa_data)

# ============================================================
# 3. AGENTS
# ============================================================

# Agent 1: Data Analyzer (no state reference)
data_analyzer_agent = Agent(
    name="DataAnalyzerAgent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    tools=[analyze_data_tool],
    instruction="""
You are the Data Analyzer Agent.

Your task:
- Use your tool 'analyze_data_tool' to analyze the M-Pesa statement.
- Assign the result to the session variable 'analysis_output'.

Example tool call (ADK understands this):
analysis_output = tools.call('analyze_data_tool')

Return only:
Analysis complete.
""",
    output_key="analysis_output"
)


# Agent 2: Insights Agent (reads {analysis_output})
insights_agent = Agent(
    name="InsightsAgent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""
You are the Insights Agent.

You receive this data:
{analysis_output}

Tasks:
- Identify SME financial patterns
- Explain spending behavior
- Highlight risks & opportunities

Save the result into insights_output.

Return only:
Insights complete.
""",
    output_key="insights_output"
)

# Agent 3: Loan Advisor (reads {analysis_output} and {insights_output})
loan_advisor_agent = Agent(
    name="LoanAdvisorAgent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""
You are the Loan Advisory Agent.

You receive:
Analysis: {analysis_output}
Insights: {insights_output}

Tasks:
- Assess SME repayment ability
- Recommend suitable loan type & amount
- Provide repayment insights

Save the result into loan_advice_output.

Return only:
Loan advice complete.
""",
    output_key="loan_advice_output"
)

# ============================================================
# 4. SYSTEM PIPELINE
# ============================================================

sme_financial_system = SequentialAgent(
    name="SMEFinancialSystem",
    sub_agents=[
        data_analyzer_agent,
        insights_agent,
        loan_advisor_agent
    ]
)

runner = InMemoryRunner(agent=sme_financial_system)

# ============================================================
# 5. RUN PIPELINE
# ============================================================

response = await runner.run_debug("Analyze my statement and give me insights + loan advice")

# Print final response
print(response)
# Out:
# ✅ Cleaned up old database files
#
#  ### Created new session: debug_session_id
#
# User > Analyze my statement and give me insights + loan advice
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/expressions.py:73: RuntimeWarning: invalid value encountered in greater
#   return op(a, b)
# DataAnalyzerAgent > This is a summary of your M-Pesa statement:
#
# **Balance Statistics:**
# *   Your average balance was 155.92.
# *   Your starting balance was 61.79, and your ending balance is 0.38.
# *   The highest balance you reached was 960.38, and the lowest was 0.35.
#
# **Financial Overview:**
# *   Your total income was 52,769.59.
# *   Your total withdrawals amounted to 55,391.65.
#
# **Spending Insights:**
# *   There is no data on spending by category.
#
# **Loan Advice:**
# Since your withdrawals exceed your income, it suggests you may be living beyond your means or relying on credit. To improve your financial health, I recommend:
# *   **Budgeting:** Track your expenses to identify areas where you can cut back.
# *   **Increasing Income:** Explore options for additional income streams.
# *   **Reducing Debt:** Prioritize paying off any existing loans or credit.
# *   **Saving:** Aim to build an emergency fund to avoid relying on loans for unexpected expenses.
#
# If you're considering a loan, carefully assess your ability to repay it, considering your current income and expenses. It would be wise to consult with a financial advisor to discuss your specific situation and borrowing options.
# InsightsAgent > **SME Financial Patterns:**
#
# *   **Income vs. Outflow Imbalance:** The data shows a net outflow of funds, with total withdrawals exceeding total income (55,391.65 withdrawn vs. 52,769.59 income). This indicates a potential cash flow problem where expenses are outpacing earnings.
# *   **Declining Balance:** The ending balance (0.38) is significantly lower than the starting balance (61.79), and the average balance (155.92) is also being pulled down by this trend. This suggests a consistent depletion of funds over the statement period.
# *   **High Transaction Volume (Implied):** While not explicitly stated, the significant difference between income and withdrawals, coupled with a high peak balance (960.38), suggests a high volume of transactions, both incoming and outgoing.
#
# **Spending Behavior:**
#
# *   **Lack of Categorization:** There is no data on spending by category, making it impossible to identify specific areas of expenditure or patterns in how the money is being spent. This prevents a granular analysis of spending habits.
# *   **High Withdrawal Activity:** The total withdrawal amount exceeding income is the primary indicator of spending behavior. It suggests that the individual is spending more than they are earning, potentially on essential living expenses, discretionary spending, or debt repayment.
#
# **Risks & Opportunities:**
#
# *   **Risks:**
#     *   **Financial Strain:** Living beyond means and relying on credit can lead to accumulating debt, poor credit scores, and significant financial stress.
#     *   **Vulnerability to Unexpected Expenses:** With a low ending balance and no emergency fund (implied by the need for loans), unexpected expenses could lead to a crisis.
#     *   **Potential for Debt Spiral:** If withdrawals continue to exceed income without corrective action, it could lead to a cycle of debt that is difficult to escape.
# *   **Opportunities:**
#     *   **Budgeting Implementation:** The lack of spending data presents a clear opportunity to implement a robust budgeting system to gain control over expenditures.
#     *   **Income Enhancement:** Exploring additional income streams could significantly improve the financial outlook and reduce reliance on borrowing.
#     *   **Debt Reduction Strategy:** Developing and executing a plan to reduce existing debt will free up cash flow and improve overall financial health.
#     *   **Emergency Fund Creation:** Building an emergency fund will provide a safety net for unforeseen circumstances, reducing the need for high-interest loans.
#     *   **Financial Advisory Consultation:** Seeking professional advice can provide tailored strategies for managing finances and exploring responsible borrowing if needed.
#
# Insights complete.
# LoanAdvisorAgent > **Repayment Ability Assessment:**
#
# Based on the provided M-Pesa statement, your repayment ability is currently **low**. Here's why:
#
# *   **Consistent Outflow Exceeding Inflow:** Your total withdrawals ($55,391.65) significantly exceeded your total income ($52,769.59). This indicates a net loss of funds over the statement period.
# *   **Declining Balance:** Your ending balance ($0.38) is drastically lower than your starting balance ($61.79), and the average balance is also low. This suggests a trend of depleting funds rather than accumulating them.
# *   **Lack of Savings:** The very low ending balance implies little to no available savings for loan repayments, especially for unexpected expenses.
#
# **Recommended Loan Type and Amount:**
#
# Given your current financial situation, it is **not advisable to take out a new loan at this time**. The risk of defaulting is high due to the demonstrated inability to manage current outflows.
#
# If a loan is absolutely necessary, it should be:
#
# *   **A small, short-term loan:** This would minimize the overall financial burden and reduce the repayment period.
# *   **For a critical, income-generating purpose:** The loan should ideally be used for an investment that has a clear and quantifiable path to increasing your income to cover the repayment and provide a surplus.
# *   **Amount:** The amount should be strictly limited to what you can demonstrate, with a high degree of certainty, that you can repay within a short period. This would likely be a very small fraction of your current monthly income, perhaps not exceeding 10-15% of your total income, assuming you can also cover your essential expenses.
#
# **Repayment Insights:**
#
# *   **Prioritize Existing Financial Health:** Before considering any new loan, focus on addressing the existing income-outflow imbalance. Implement a strict budget, track all expenses meticulously, and identify areas for significant cost reduction.
# *   **Increase Income Streams:** Actively seek opportunities to increase your income. This could involve side hustles, negotiating a raise, or seeking higher-paying employment.
# *   **Debt Management:** If you have existing debts, prioritize paying them down. High interest payments on existing debt can exacerbate your current outflow problem.
# *   **Emergency Fund:** Build an emergency fund. Even a small fund of 1-2 months of essential living expenses can prevent you from needing to rely on loans for unexpected events.
# *   **Financial Consultation:** Strongly consider consulting with a financial advisor. They can help you create a personalized debt management and budgeting plan, assess your true borrowing capacity, and explore responsible financial strategies.
#
# Loan advice complete.
# [Event(model_version='gemini-2.5-flash-lite', content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={},
#         id='adk-15274097-45e4-463b-bb68-cd7123448b1d',
#         name='analyze_mpesa_data'
#       )
#     ),
#   ],
#   role='model'
# ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=13,
#   prompt_token_count=131,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=131
#     ),
#   ],
#   total_token_count=144
# ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-32a8ed0f-ef40-4b1b-a1a3-fb631f3a872d', author='DataAnalyzerAgent', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=set(), branch=None, id='4ba5d0c1-0397-4d03-b191-e03285b5cf01', timestamp=1763458112.706649), Event(model_version=None, content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-15274097-45e4-463b-bb68-cd7123448b1d',
#         name='analyze_mpesa_data',
#         response={
#           'balance_stats': {
#             'avg_balance': 155.92126466753587,
#             'end_balance': 0.38,
#             'max_balance': 960.38,
#             'min_balance': 0.35,
#             'start_balance': 61.79
#           },
#           'category_spending': {},
#           'income_total': 52769.59,
#           'withdrawal_total': -55391.65
#         }
#       )
#     ),
#   ],
#   role='user'
# ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=None, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=None, live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-32a8ed0f-ef40-4b1b-a1a3-fb631f3a872d', author='DataAnalyzerAgent', actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='c5fd8dd6-f880-4541-b404-b5c71587cbf2', timestamp=1763458113.540903), Event(model_version='gemini-2.5-flash-lite', content=Content(
#   parts=[
#     Part(
#       text="""This is a summary of your M-Pesa statement:
#
# **Balance Statistics:**
# *   Your average balance was 155.92.
# *   Your starting balance was 61.79, and your ending balance is 0.38.
# *   The highest balance you reached was 960.38, and the lowest was 0.35.
#
# **Financial Overview:**
# *   Your total income was 52,769.59.
# *   Your total withdrawals amounted to 55,391.65.
#
# **Spending Insights:**
# *   There is no data on spending by category.
#
# **Loan Advice:**
# Since your withdrawals exceed your income, it suggests you may be living beyond your means or relying on credit. To improve your financial health, I recommend:
# *   **Budgeting:** Track your expenses to identify areas where you can cut back.
# *   **Increasing Income:** Explore options for additional income streams.
# *   **Reducing Debt:** Prioritize paying off any existing loans or credit.
# *   **Saving:** Aim to build an emergency fund to avoid relying on loans for unexpected expenses.
#
# If you're considering a loan, carefully assess your ability to repay it, considering your current income and expenses. It would be wise to consult with a financial advisor to discuss your specific situation and borrowing options."""
#     ),
#   ],
#   role='model'
# ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=293,
#   prompt_token_count=269,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=269
#     ),
#   ],
#   total_token_count=562
# ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-32a8ed0f-ef40-4b1b-a1a3-fb631f3a872d', author='DataAnalyzerAgent', actions=EventActions(skip_summarization=None, state_delta={'analysis_output': "This is a summary of your M-Pesa statement:\n\n**Balance Statistics:**\n*   Your average balance was 155.92.\n*   Your starting balance was 61.79, and your ending balance is 0.38.\n*   The highest balance you reached was 960.38, and the lowest was 0.35.\n\n**Financial Overview:**\n*   Your total income was 52,769.59.\n*   Your total withdrawals amounted to 55,391.65.\n\n**Spending Insights:**\n*   There is no data on spending by category.\n\n**Loan Advice:**\nSince your withdrawals exceed your income, it suggests you may be living beyond your means or relying on credit. To improve your financial health, I recommend:\n*   **Budgeting:** Track your expenses to identify areas where you can cut back.\n*   **Increasing Income:** Explore options for additional income streams.\n*   **Reducing Debt:** Prioritize paying off any existing loans or credit.\n*   **Saving:** Aim to build an emergency fund to avoid relying on loans for unexpected expenses.\n\nIf you're considering a loan, carefully assess your ability to repay it, considering your current income and expenses. It would be wise to consult with a financial advisor to discuss your specific situation and borrowing options."}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='88079244-4413-45ec-ab6d-5633f7da136c', timestamp=1763458113.54189), Event(model_version='gemini-2.5-flash-lite', content=Content(
#   parts=[
#     Part(
#       text="""**SME Financial Patterns:**
#
# *   **Income vs. Outflow Imbalance:** The data shows a net outflow of funds, with total withdrawals exceeding total income (55,391.65 withdrawn vs. 52,769.59 income). This indicates a potential cash flow problem where expenses are outpacing earnings.
# *   **Declining Balance:** The ending balance (0.38) is significantly lower than the starting balance (61.79), and the average balance (155.92) is also being pulled down by this trend. This suggests a consistent depletion of funds over the statement period.
# *   **High Transaction Volume (Implied):** While not explicitly stated, the significant difference between income and withdrawals, coupled with a high peak balance (960.38), suggests a high volume of transactions, both incoming and outgoing.
#
# **Spending Behavior:**
#
# *   **Lack of Categorization:** There is no data on spending by category, making it impossible to identify specific areas of expenditure or patterns in how the money is being spent. This prevents a granular analysis of spending habits.
# *   **High Withdrawal Activity:** The total withdrawal amount exceeding income is the primary indicator of spending behavior. It suggests that the individual is spending more than they are earning, potentially on essential living expenses, discretionary spending, or debt repayment.
#
# **Risks & Opportunities:**
#
# *   **Risks:**
#     *   **Financial Strain:** Living beyond means and relying on credit can lead to accumulating debt, poor credit scores, and significant financial stress.
#     *   **Vulnerability to Unexpected Expenses:** With a low ending balance and no emergency fund (implied by the need for loans), unexpected expenses could lead to a crisis.
#     *   **Potential for Debt Spiral:** If withdrawals continue to exceed income without corrective action, it could lead to a cycle of debt that is difficult to escape.
# *   **Opportunities:**
#     *   **Budgeting Implementation:** The lack of spending data presents a clear opportunity to implement a robust budgeting system to gain control over expenditures.
#     *   **Income Enhancement:** Exploring additional income streams could significantly improve the financial outlook and reduce reliance on borrowing.
#     *   **Debt Reduction Strategy:** Developing and executing a plan to reduce existing debt will free up cash flow and improve overall financial health.
#     *   **Emergency Fund Creation:** Building an emergency fund will provide a safety net for unforeseen circumstances, reducing the need for high-interest loans.
#     *   **Financial Advisory Consultation:** Seeking professional advice can provide tailored strategies for managing finances and exploring responsible borrowing if needed.
#
# Insights complete."""
#     ),
#   ],
#   role='model'
# ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=551,
#   prompt_token_count=831,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=831
#     ),
#   ],
#   total_token_count=1382
# ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-32a8ed0f-ef40-4b1b-a1a3-fb631f3a872d', author='InsightsAgent', actions=EventActions(skip_summarization=None, state_delta={'insights_output': '**SME Financial Patterns:**\n\n*   **Income vs. Outflow Imbalance:** The data shows a net outflow of funds, with total withdrawals exceeding total income (55,391.65 withdrawn vs. 52,769.59 income). This indicates a potential cash flow problem where expenses are outpacing earnings.\n*   **Declining Balance:** The ending balance (0.38) is significantly lower than the starting balance (61.79), and the average balance (155.92) is also being pulled down by this trend. This suggests a consistent depletion of funds over the statement period.\n*   **High Transaction Volume (Implied):** While not explicitly stated, the significant difference between income and withdrawals, coupled with a high peak balance (960.38), suggests a high volume of transactions, both incoming and outgoing.\n\n**Spending Behavior:**\n\n*   **Lack of Categorization:** There is no data on spending by category, making it impossible to identify specific areas of expenditure or patterns in how the money is being spent. This prevents a granular analysis of spending habits.\n*   **High Withdrawal Activity:** The total withdrawal amount exceeding income is the primary indicator of spending behavior. It suggests that the individual is spending more than they are earning, potentially on essential living expenses, discretionary spending, or debt repayment.\n\n**Risks & Opportunities:**\n\n*   **Risks:**\n    *   **Financial Strain:** Living beyond means and relying on credit can lead to accumulating debt, poor credit scores, and significant financial stress.\n    *   **Vulnerability to Unexpected Expenses:** With a low ending balance and no emergency fund (implied by the need for loans), unexpected expenses could lead to a crisis.\n    *   **Potential for Debt Spiral:** If withdrawals continue to exceed income without corrective action, it could lead to a cycle of debt that is difficult to escape.\n*   **Opportunities:**\n    *   **Budgeting Implementation:** The lack of spending data presents a clear opportunity to implement a robust budgeting system to gain control over expenditures.\n    *   **Income Enhancement:** Exploring additional income streams could significantly improve the financial outlook and reduce reliance on borrowing.\n    *   **Debt Reduction Strategy:** Developing and executing a plan to reduce existing debt will free up cash flow and improve overall financial health.\n    *   **Emergency Fund Creation:** Building an emergency fund will provide a safety net for unforeseen circumstances, reducing the need for high-interest loans.\n    *   **Financial Advisory Consultation:** Seeking professional advice can provide tailored strategies for managing finances and exploring responsible borrowing if needed.\n\nInsights complete.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='13e019f5-e8d4-49da-a13d-226db875cf79', timestamp=1763458115.153162), Event(model_version='gemini-2.5-flash-lite', content=Content(
#   parts=[
#     Part(
#       text="""**Repayment Ability Assessment:**
#
# Based on the provided M-Pesa statement, your repayment ability is currently **low**. Here's why:
#
# *   **Consistent Outflow Exceeding Inflow:** Your total withdrawals ($55,391.65) significantly exceeded your total income ($52,769.59). This indicates a net loss of funds over the statement period.
# *   **Declining Balance:** Your ending balance ($0.38) is drastically lower than your starting balance ($61.79), and the average balance is also low. This suggests a trend of depleting funds rather than accumulating them.
# *   **Lack of Savings:** The very low ending balance implies little to no available savings for loan repayments, especially for unexpected expenses.
#
# **Recommended Loan Type and Amount:**
#
# Given your current financial situation, it is **not advisable to take out a new loan at this time**. The risk of defaulting is high due to the demonstrated inability to manage current outflows.
#
# If a loan is absolutely necessary, it should be:
#
# *   **A small, short-term loan:** This would minimize the overall financial burden and reduce the repayment period.
# *   **For a critical, income-generating purpose:** The loan should ideally be used for an investment that has a clear and quantifiable path to increasing your income to cover the repayment and provide a surplus.
# *   **Amount:** The amount should be strictly limited to what you can demonstrate, with a high degree of certainty, that you can repay within a short period. This would likely be a very small fraction of your current monthly income, perhaps not exceeding 10-15% of your total income, assuming you can also cover your essential expenses.
#
# **Repayment Insights:**
#
# *   **Prioritize Existing Financial Health:** Before considering any new loan, focus on addressing the existing income-outflow imbalance. Implement a strict budget, track all expenses meticulously, and identify areas for significant cost reduction.
# *   **Increase Income Streams:** Actively seek opportunities to increase your income. This could involve side hustles, negotiating a raise, or seeking higher-paying employment.
# *   **Debt Management:** If you have existing debts, prioritize paying them down. High interest payments on existing debt can exacerbate your current outflow problem.
# *   **Emergency Fund:** Build an emergency fund. Even a small fund of 1-2 months of essential living expenses can prevent you from needing to rely on loans for unexpected events.
# *   **Financial Consultation:** Strongly consider consulting with a financial advisor. They can help you create a personalized debt management and budgeting plan, assess your true borrowing capacity, and explore responsible financial strategies.
#
# Loan advice complete."""
#     ),
#   ],
#   role='model'
# ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=563,
#   prompt_token_count=1953,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=1953
#     ),
#   ],
#   total_token_count=2516
# ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-32a8ed0f-ef40-4b1b-a1a3-fb631f3a872d', author='LoanAdvisorAgent', actions=EventActions(skip_summarization=None, state_delta={'loan_advice_output': "**Repayment Ability Assessment:**\n\nBased on the provided M-Pesa statement, your repayment ability is currently **low**. Here's why:\n\n*   **Consistent Outflow Exceeding Inflow:** Your total withdrawals ($55,391.65) significantly exceeded your total income ($52,769.59). This indicates a net loss of funds over the statement period.\n*   **Declining Balance:** Your ending balance ($0.38) is drastically lower than your starting balance ($61.79), and the average balance is also low. This suggests a trend of depleting funds rather than accumulating them.\n*   **Lack of Savings:** The very low ending balance implies little to no available savings for loan repayments, especially for unexpected expenses.\n\n**Recommended Loan Type and Amount:**\n\nGiven your current financial situation, it is **not advisable to take out a new loan at this time**. The risk of defaulting is high due to the demonstrated inability to manage current outflows.\n\nIf a loan is absolutely necessary, it should be:\n\n*   **A small, short-term loan:** This would minimize the overall financial burden and reduce the repayment period.\n*   **For a critical, income-generating purpose:** The loan should ideally be used for an investment that has a clear and quantifiable path to increasing your income to cover the repayment and provide a surplus.\n*   **Amount:** The amount should be strictly limited to what you can demonstrate, with a high degree of certainty, that you can repay within a short period. This would likely be a very small fraction of your current monthly income, perhaps not exceeding 10-15% of your total income, assuming you can also cover your essential expenses.\n\n**Repayment Insights:**\n\n*   **Prioritize Existing Financial Health:** Before considering any new loan, focus on addressing the existing income-outflow imbalance. Implement a strict budget, track all expenses meticulously, and identify areas for significant cost reduction.\n*   **Increase Income Streams:** Actively seek opportunities to increase your income. This could involve side hustles, negotiating a raise, or seeking higher-paying employment.\n*   **Debt Management:** If you have existing debts, prioritize paying them down. High interest payments on existing debt can exacerbate your current outflow problem.\n*   **Emergency Fund:** Build an emergency fund. Even a small fund of 1-2 months of essential living expenses can prevent you from needing to rely on loans for unexpected events.\n*   **Financial Consultation:** Strongly consider consulting with a financial advisor. They can help you create a personalized debt management and budgeting plan, assess your true borrowing capacity, and explore responsible financial strategies.\n\nLoan advice complete."}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='e2987519-ca21-425d-9c15-0cff3565cc94', timestamp=1763458118.057668)]
